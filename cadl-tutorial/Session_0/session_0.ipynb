# %%
import os
import urllib.request
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
if not os.path.exists('img_align_celeb/'):
    os.mkdir('img_align_celeb')
    print ("Directory created")
else:
    print ("It already exists")
# Out:
# Directory created

# %%
for i in range (1,11):
    f = '000%03d.jpg' % i
    url = 'https://s3.amazonaws.com/cadl/celeb-align/' + f
    print (url, end='\n')
    urllib.request.urlretrieve(url, os.path.join('img_align_celeb',f))
# Out:
# https://s3.amazonaws.com/cadl/celeb-align/000001.jpg
# https://s3.amazonaws.com/cadl/celeb-align/000002.jpg
# https://s3.amazonaws.com/cadl/celeb-align/000003.jpg
# https://s3.amazonaws.com/cadl/celeb-align/000004.jpg
# https://s3.amazonaws.com/cadl/celeb-align/000005.jpg
# https://s3.amazonaws.com/cadl/celeb-align/000006.jpg
# https://s3.amazonaws.com/cadl/celeb-align/000007.jpg
# https://s3.amazonaws.com/cadl/celeb-align/000008.jpg
# https://s3.amazonaws.com/cadl/celeb-align/000009.jpg
# https://s3.amazonaws.com/cadl/celeb-align/000010.jpg

# %%
a = os.listdir('img_align_celeb')

# %%
[file_i for file_i in os.listdir('img_align_celeb') if '.jpg' in file_i]
# Out:
# ['000001.jpg',
#  '000002.jpg',
#  '000003.jpg',
#  '000004.jpg',
#  '000005.jpg',
#  '000006.jpg',
#  '000007.jpg',
#  '000008.jpg',
#  '000009.jpg',
#  '000010.jpg']

# %%
files = [file_i for file_i in os.listdir('img_align_celeb')
         if '.jpg' in file_i and '00000' in file_i]

# %%
os.listdir('a://Pictures/Awesome_CarS/')
# Out:
# ['2013_lamborghini_veneno_interior-wallpaper-2560x1440.jpg',
#  '2013_lamborghini_veneno_speed-wallpaper-2400x1350.jpg',
#  '3d_cars_12-wallpaper-1920x1080.jpg',
#  '3d_cars_13-wallpaper-1920x1080.jpg',
#  'audi_666-wallpaper-1920x1080.jpg',
#  'audi_cars_motors_15-wallpaper-1920x1080.jpg',
#  'audi___legend_perspective-wallpaper-3840x2160.jpg',
#  'chevy_camaro_classic_cars-wallpaper-1920x1080.jpg',
#  'lamborghini_aventador_roadside-wallpaper-1920x1080.jpg',
#  'lamborghini_cars_city-wallpaper-1920x1080.jpg']

# %%
temp = [x for x in os.listdir('a://Pictures/')
        if '.gif' in x]

# %%
temp
# Out:
# ['6b1d435526e09cd4be289da42df7e999.gif',
#  'abstract.gif',
#  'catgiphy.gif',
#  'Emo_Life_Story.gif',
#  'finger_control.gif',
#  'giphy (1).gif',
#  'giphy.gif',
#  'how-a-key-works.gif',
#  'so cute cat.gif',
#  'surya_namaskar.gif',
#  'tumblr_nwdpq2IauE1qzcdp3o1_500.gif']

# %%
temp[1]
# Out:
# 'abstract.gif'

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
files
# Out:
# ['000001.jpg',
#  '000002.jpg',
#  '000003.jpg',
#  '000004.jpg',
#  '000005.jpg',
#  '000006.jpg',
#  '000007.jpg',
#  '000008.jpg',
#  '000009.jpg']

# %%
import numpy as np

# %%
print (os.path.join('img_align_celeb/', files[0]))
img = plt.imread(os.path.join('img_align_celeb/', files[0]))
# Out:
# img_align_celeb/000001.jpg

# %%
filenames = [os.path.join('img_align_celeb/', file_i) for file_i in os.listdir('img_align_celeb/')
            if '.jpg' in file_i]

# %%
filenames
# Out:
# ['img_align_celeb/000001.jpg',
#  'img_align_celeb/000002.jpg',
#  'img_align_celeb/000003.jpg',
#  'img_align_celeb/000004.jpg',
#  'img_align_celeb/000005.jpg',
#  'img_align_celeb/000006.jpg',
#  'img_align_celeb/000007.jpg',
#  'img_align_celeb/000008.jpg',
#  'img_align_celeb/000009.jpg',
#  'img_align_celeb/000010.jpg']

# %%
img = plt.imread(filenames[2])
#img = plt.imread('a://Pictures/Awesome_CarS/2013_lamborghini_veneno_interior-wallpaper-2560x1440.jpg')

# %%
img.shape
# Out:
# (218, 178, 3)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (218, 178, 3)

# %%
plt.figure()
plt.imshow(img[:,:,0])

plt.figure()
plt.imshow(img[:,:,1])

plt.figure()
plt.imshow(img[:,:,2])

# %%
np.min(img), np.max(img)
# Out:
# (40, 255)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.astype(np.float32)
# Out:
# array([[[ 255.,  255.,  255.],
#         [ 255.,  255.,  255.],
#         [ 255.,  255.,  255.],
#         ...,
#         [ 255.,  255.,  255.],
#         [ 255.,  255.,  255.],
#         [ 255.,  255.,  255.]],
#
#        [[ 255.,  255.,  255.],
#         [ 255.,  255.,  255.],
#         [ 255.,  255.,  255.],
#         ...,
#         [ 255.,  255.,  255.],
#         [ 255.,  255.,  255.],
#         [ 255.,  255.,  255.]],
#
#        [[ 255.,  255.,  255.],
#         [ 255.,  255.,  255.],
#         [ 255.,  255.,  255.],
#         ...,
#         [ 255.,  255.,  255.],
#         [ 255.,  255.,  255.],
#         [ 255.,  255.,  255.]],
#
#        ...,
#        [[ 146.,  110.,   86.],
#         [ 147.,  111.,   87.],
#         [ 150.,  114.,   88.],
#         ...,
#         [  91.,   89.,   92.],
#         [  92.,   92.,   94.],
#         [  92.,   92.,   94.]],
#
#        [[ 135.,  100.,   78.],
#         [ 136.,  102.,   77.],
#         [ 139.,  105.,   80.],
#         ...,
# ...

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(plt.imread(filenames[0]))

# %%
print(np.random.randint(0, len(filenames)))
# Out:
# 9

# %%
filename = filenames[np.random.randint(0, len(filenames))]
img = plt.imread(filename)
plt.imshow(img)

# %%
def imcrop_tosquare(img):
    """Make any image a square image.

    Parameters
    ----------
    img : np.ndarray
        Input image to crop, assumed at least 2d.

    Returns
    -------
    crop : np.ndarray
        Cropped image.
    """
    if img.shape[0] > img.shape[1]:
        extra = (img.shape[0] - img.shape[1])
        if extra % 2 == 0:
            crop = img[extra // 2:-extra // 2, :]
        else:
            crop = img[max(0, extra // 2 + 1):min(-1, -(extra // 2)), :]
    elif img.shape[1] > img.shape[0]:
        extra = (img.shape[1] - img.shape[0])
        if extra % 2 == 0:
            crop = img[:, extra // 2:-extra // 2]
        else:
            crop = img[:, max(0, extra // 2 + 1):min(-1, -(extra // 2))]
    else:
        crop = img
    return crop

# %%
def imcrop(img, amt):
    if amt <= 0 or amt >= 1:
        return img
    row_i = int(img.shape[0] * amt) // 2
    col_i = int(img.shape[1] * amt) // 2
    return img[row_i:-row_i, col_i:-col_i]

# %%
def imcrop_arbitrary(img, x, y):
    return img[0:x, 0:y]

# %%
plt.figure()
plt.imshow(img)

plt.figure()
plt.imshow(imcrop_tosquare(img))

plt.figure()
plt.imshow(imcrop(img, .25))

plt.figure()
plt.imshow(imcrop_arbitrary(img, 100, 100))

# %%
from scipy.misc import imresize

# %%
square = imcrop_tosquare(img)

# %%
crop = imcrop(square, .2)

# %%
rsz = imresize(crop, (64,64))
plt.imshow(rsz, interpolation='nearest')

# %%
plt.imshow(rsz)

# %%
mean_img = np.mean(rsz, axis=2)
print (mean_img.shape)
# Out:
# (64, 64)

# %%
plt.imshow(mean_img, cmap='gray')

# %%
filenames
# Out:
# ['img_align_celeb/000001.jpg',
#  'img_align_celeb/000002.jpg',
#  'img_align_celeb/000003.jpg',
#  'img_align_celeb/000004.jpg',
#  'img_align_celeb/000005.jpg',
#  'img_align_celeb/000006.jpg',
#  'img_align_celeb/000007.jpg',
#  'img_align_celeb/000008.jpg',
#  'img_align_celeb/000009.jpg',
#  'img_align_celeb/000010.jpg']

# %%
imgs = []
for file_i in filenames:
    img = plt.imread(file_i)
    square = imcrop_tosquare(img)
    crop = imcrop(img, 0.2)
    rsz = imresize(crop, (64, 64))
    imgs.append(rsz)
print(len(imgs))
# Out:
# 10

# %%
plt.imshow(imgs[3])

# %%
data = np.array(imgs)

# %%
data.shape
# Out:
# (10, 64, 64, 3)

# %%
data_temp = np.concatenate([img_i[np.newaxis] for img_i in imgs], axis=0)
data_temp.shape
# Out:
# (10, 64, 64, 3)
